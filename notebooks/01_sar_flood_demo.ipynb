# %% [markdown]
# # SAR flood mapping demo
# Synthetic local arrays + Sentinel-1 GEE template.

# %%
from src.data_generation import generate_sar
from src.flood import flood_from_change
pre,post,truth=generate_sar()
change,pred=flood_from_change(pre,post)
truth.sum(), pred.sum()
