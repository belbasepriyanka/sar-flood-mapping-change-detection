# %% [markdown]
# # AI Flood Intelligence & Event Mapping
# Synthetic portfolio demonstration covering change detection, validation, confidence, uncertainty and exposure-based prioritization.

# %%
from src.pipeline import generate_event, detect_flood, event_summary
from src.risk import add_risk_score
from src.validation import classification_metrics
df = add_risk_score(detect_flood(generate_event()))
classification_metrics(df.flood_truth, df.pred_flood), event_summary(df)
